# %%
import os

def header():
    '''fungsi Header'''
    os.system("clear")
    # os.system("cls")
    print(f"\n{'PROGRAM MENGHITUNG LUAS':^40}")
    print(f"{'DAN KELILING PERSEGI PANJANG':^40}")
    print(f"{'-'*40:^40}")

def input_user():
    '''fungsi input user'''
    # Mengambil input user
    lebar = float(input("Masukan nilai lebar: "))
    panjang = float(input("Masukan nilai panjang: "))

    return lebar,panjang

def hitung_luas(lebar,panjang):
    '''fungsi luas'''
    return lebar*panjang

def hitung_keliling(lebar,panjang):
    '''fungsi keliling'''
    return 2*(lebar+panjang)

def display(message,value):
    '''fungsi display'''
    print(f"hasil perhitungan {message} = {value}")


# Program utamanya
while True:
    header()
    LEBAR,PANJANG = input_user()
    LUAS = hitung_luas(LEBAR,PANJANG)
    KELILING = hitung_keliling(LEBAR,PANJANG)

    display("luas", LUAS)
    display("keliling", KELILING)

    isContinue = input("apakah lanjut (y/n)? ")
    if isContinue == "n":
        break
# Out:
#         PROGRAM MENGHITUNG LUAS
#       DAN KELILING PERSEGI PANJANG
# ----------------------------------------
# hasil perhitungan luas = 849238364.0730282
# hasil perhitungan keliling = 118991.33064
#
#         PROGRAM MENGHITUNG LUAS
#       DAN KELILING PERSEGI PANJANG
# ----------------------------------------
# hasil perhitungan luas = 277206769084.0616
# hasil perhitungan keliling = 2223112.2160400003
